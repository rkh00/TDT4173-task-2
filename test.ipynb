# %% [markdown]
# # First we want to see the correlation

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_parquet("data/data/A/X_train_observed.parquet")

# df.dropna(inplace=True)
df_for_corr = df.iloc[: , 1:]
# print(df_for_corr.corr())

# df

sns.heatmap(df_for_corr.corr())

df

# plt.matshow(df.iloc[: , 1:].corr())
# plt.set_cmap('coolwarm')
# plt.xlabel = df_for_corr.columns
# plt.addlabels
# plt.show()
# Out:
#              date_forecast  absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 0      2019-06-02 22:00:00                       7.7                1.230
# 1      2019-06-02 22:15:00                       7.7                1.229
# 2      2019-06-02 22:30:00                       7.7                1.228
# 3      2019-06-02 22:45:00                       7.7                1.226
# 4      2019-06-02 23:00:00                       7.7                1.225
# ...                    ...                       ...                  ...
# 118664 2022-10-21 00:00:00                       5.0                1.292
# 118665 2022-10-21 00:15:00                       5.0                1.292
# 118666 2022-10-21 00:30:00                       5.0                1.292
# 118667 2022-10-21 00:45:00                       5.0                1.292
# 118668 2022-10-21 01:00:00                       5.0                1.292
#
#         ceiling_height_agl:m  clear_sky_energy_1h:J  clear_sky_rad:W  \
# ...

# %%
y = pd.read_parquet("data/data/A/train_targets.parquet")

# df['date_forecast'] = pd.to_datetime(df['date_forecast'])
# y['time'] = pd.to_datetime(y['time'])

df_reindexed = df
y_reindexed = y


df_reindexed.set_index('date_forecast', inplace=True)
y_reindexed.set_index('time', inplace=True)

y_resampled = y_reindexed.resample('15T').ffill()
y_resampled
# Out:
#                      pv_measurement
# time
# 2019-06-02 22:00:00             0.0
# 2019-06-02 22:15:00             0.0
# 2019-06-02 22:30:00             0.0
# 2019-06-02 22:45:00             0.0
# 2019-06-02 23:00:00             0.0
# ...                             ...
# 2023-04-30 22:00:00             0.0
# 2023-04-30 22:15:00             0.0
# 2023-04-30 22:30:00             0.0
# 2023-04-30 22:45:00             0.0
# 2023-04-30 23:00:00             0.0
#
# [137093 rows x 1 columns]

# %%
# y['time'] = y['time'].resample('15T').asfreq()
merged_df = df_reindexed.merge(y_resampled, left_index=True, right_index=True, how='inner')
# merged_df.reset_index(inplace=True)
merged_df
# Out:
#                      absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 2019-06-02 22:00:00                       7.7                1.230
# 2019-06-02 22:15:00                       7.7                1.229
# 2019-06-02 22:30:00                       7.7                1.228
# 2019-06-02 22:45:00                       7.7                1.226
# 2019-06-02 23:00:00                       7.7                1.225
# ...                                       ...                  ...
# 2022-10-21 00:00:00                       5.0                1.292
# 2022-10-21 00:15:00                       5.0                1.292
# 2022-10-21 00:30:00                       5.0                1.292
# 2022-10-21 00:45:00                       5.0                1.292
# 2022-10-21 01:00:00                       5.0                1.292
#
#                      ceiling_height_agl:m  clear_sky_energy_1h:J  \
# 2019-06-02 22:00:00           1744.900024                    0.0
# ...

# %%
X_train = merged_df.iloc[: , :-1]
Y_train = merged_df.iloc[: , -1:]
# Out:
#                      absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 2019-06-02 22:00:00                       7.7                1.230
# 2019-06-02 22:15:00                       7.7                1.229
# 2019-06-02 22:30:00                       7.7                1.228
# 2019-06-02 22:45:00                       7.7                1.226
# 2019-06-02 23:00:00                       7.7                1.225
# ...                                       ...                  ...
# 2022-10-21 00:00:00                       5.0                1.292
# 2022-10-21 00:15:00                       5.0                1.292
# 2022-10-21 00:30:00                       5.0                1.292
# 2022-10-21 00:45:00                       5.0                1.292
# 2022-10-21 01:00:00                       5.0                1.292
#
#                      ceiling_height_agl:m  clear_sky_energy_1h:J  \
# 2019-06-02 22:00:00           1744.900024                    0.0
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from xgboost import XGBRegressor

#Tuning
params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
}

model = XGBRegressor()
random_search = RandomizedSearchCV(model, param_distributions= params, n_iter = 100, scoring="neg_mean_squared_error", n_jobs=3, verbose=3)
random_search.fit(X, y)
