# %%
import pandas as pd

df = pd.read_parquet("data/data/A/X_train_observed.parquet")

# df.dropna(inplace=True)
df
# Out:
#             date_forecast  absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 17422 2019-12-01 09:30:00                       4.8                1.272
# 17423 2019-12-01 09:45:00                       4.8                1.273
# 17424 2019-12-01 10:00:00                       4.9                1.273
# 17425 2019-12-01 10:15:00                       4.8                1.273
# 17426 2019-12-01 10:30:00                       4.8                1.273
# ...                   ...                       ...                  ...
# 91252 2022-01-08 11:00:00                       2.8                1.284
# 91253 2022-01-08 11:15:00                       2.8                1.284
# 91254 2022-01-08 11:30:00                       2.8                1.283
# 91255 2022-01-08 11:45:00                       2.8                1.283
# 91256 2022-01-08 12:00:00                       2.8                1.283
#
#        ceiling_height_agl:m  clear_sky_energy_1h:J  clear_sky_rad:W  \
# ...
